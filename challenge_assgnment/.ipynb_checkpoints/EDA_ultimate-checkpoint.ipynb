# %%
import json
import pandas as pd
from datetime import datetime 
from datetime import timedelta
import numpy as np
from collections import defaultdict
import matplotlib.pyplot as plt
import seaborn as sns

# %%
f_1 = open('logins.json')

# %%
data_1 = json.load(f_1)

# %%
df_login = pd.DataFrame(data_1)

# %%
df_login.dtypes
# Out:
# login_time    object
# dtype: object

# %%
df_login.index = pd.to_datetime(df_login['login_time'])

# %%
df_login.resample(rule='15T').count()
# Out:
#                      login_time
# login_time
# 1970-01-01 20:00:00           2
# 1970-01-01 20:15:00           6
# 1970-01-01 20:30:00           9
# 1970-01-01 20:45:00           7
# 1970-01-01 21:00:00           1
# ...                         ...
# 1970-04-13 17:45:00           5
# 1970-04-13 18:00:00           5
# 1970-04-13 18:15:00           2
# 1970-04-13 18:30:00           7
# 1970-04-13 18:45:00           6
#
# [9788 rows x 1 columns]

# %%
plt.figure(figsize=(12,6))
df_login.resample(rule='15T').count().plot();

# %%
df_agg = df_login.resample(rule='15T').count()

# %%
#now each row contains 15 min data, we can plot for 96 window to see per day pattern

# %%
df_agg.rolling(96).mean().plot()
# Out:
# <AxesSubplot:xlabel='login_time'>

# %%
#lets plot only a month day wise

# %%
df_agg.loc['1970-02'].rolling(96).mean().plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='login_time'>

# %%
#plotting the trend over a week

# %%
datetime(1970,3,1).weekday()
# Out:
# 6

# %%
unsmoothed = df_agg.loc['1970-03-01':'1970-03-07']['login_time']
trend = unsmoothed.rolling(48).mean()
pd.DataFrame({'unsmoothed':unsmoothed,'smoothed':trend}).plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='login_time'>

# %%
#from above graph its clear that demand is higher at inetrval (7-9,14-16,21-23)
#lets check for wat is the day on these days to check demand on weekend and weekdays

# %%
datetime(1970, 2, 7).weekday()
# Out:
# 5

# %%
#its saturday, so demand is higher on weekends than weekdays

# %%
#lets check demand during a weekend

# %%
df_agg.loc['1970-02-07'].rolling(24).mean().plot()
# Out:
# <AxesSubplot:xlabel='login_time'>

# %%
#demand is higher around midnight and noon

# %%
#weekday
df_agg.loc['1970-02-09'].rolling(24).mean().plot()
# Out:
# <AxesSubplot:xlabel='login_time'>

# %%
#again demand is higher around midnight and noon

# %%
#some weekday and weekend in march
df_agg.loc['1970-03'].rolling(96).mean().plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='login_time'>

# %%
datetime(1970, 3, 7).weekday()
# Out:
# 5

# %%
#saturday

# %%
df_agg.loc['1970-03-07'].rolling(24).mean().plot()
# Out:
# <AxesSubplot:xlabel='login_time'>

# %%
df_agg.loc['1970-03-12'].rolling(24).mean().plot()
# Out:
# <AxesSubplot:xlabel='login_time'>

# %% [markdown]
# # Conclusion

# %% [raw]
# From above graphs its clear that :
# Demand is higher on weekends than weekdays and around midnight and noon on both weekdays and weekends . Ultimate can offer more incentives during peak hours to get more ridres
